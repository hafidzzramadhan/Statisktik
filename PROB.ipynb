# %%
pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in d:\pop\lib\site-packages (8.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
df=pd.read_clipboard()
print(df)
# Out:
#          Nama gender  angkatan  tinggi (Cm)  waktu perjalanan           Asal
# 0       Dave       L      2023          168                60      Tangerang
# 1   Francisco      L      2023          170                30      rusunawa
# 2       Abyan      L      2023          165                45          Priuk
# 3     Michael      L      2023          167                15      Jkt Utara
# 4    partahi       L      2023          173                45      jkt utara
# 5     hafidz       L      2023          169                15         Grogol
# 6   Francisco      L      2023          170                30      rusunawa
# 7     Rayyan       L      2023          171                50      Jkt Timur
# 8   Yustianas      L      2023          173                30     Jkt Utara
# 9      Zahwa       P      2023          154                15         grogol
# 10      Dave       L      2023          168                60     Tangerang
# 11   Calista       P      2023          160               150         Bekasi
# 12     Fairuz      P      2023          156                45          Priok
# 13      Gwen       P      2023          152                17         Gambir
# 14     Briant      L      2023          167                10        Tawakal
# 15     ariel       L      2023          170                35     Klp gading
# 16     Ridho       L      2023          170                45     Cengkareng
# 17      Monic      P      2023          160                75      Jkt Timur
# 18      Sutan      L      2023          170                90        Sunter
# 19   Zulfadli      L      2023          170                45    Kp Makasar
# 20     Andrew      L      2023          172                13         tomang
# 21      ariel      L      2023          170                35     klp gading
# 22      Arik       L      2023          177                60      Tangerang
# 23   Calista       P      2023          160               150         Bekasi
# 24   Dewanto       L      2023          172                40       Tj Priok
# 25     Fadhil      L      2023          169                60         Cipadu
# 26     Kevin       L      2023          173                60    Duren Sawit
# 27     fadly       L      2023          174                75          Depok
# 28     Hakim       L      2023          170                10     Tamansari
# 29   Rayyan        L      2023          171                50      Jkt Timur
# 30   Mutiara       P      2023          160                60        Pejaten
# 31    Noval s      L      2023          177                60          Depok
# 32      HAQI       L      2023          171                60      Tangerang
# 33    rafael       L      2023          175                15  gunung sahari
# 34    Rangga       L      2023          185                90    Kota Bekasi

# %%
import mysql.connector

# Membuat koneksi ke MySQL
connection = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="houseprices"
)

# Membuat objek cursor untuk mengeksekusi kueri
cursor = connection.cursor()

try:
    # Mengeksekusi kueri SQL
    my_query = "SELECT * FROM hafidz;"
    cursor.execute(my_query)

    # Mengambil semua hasil kueri
    result = cursor.fetchall()

    # Menampilkan hasil kueri
    print("\nHasil Kueri:")
    for row in result:
        print(row)

finally:
    # Menutup kursor dan koneksi
    cursor.close()
    connection.close()
# Out:
# Hasil Kueri:
# (69100, 1600, 2, 2, 3, 'No', 'North')
# (81300, 1650, 3, 2, 3, 'No', 'North')
# (82300, 1910, 3, 2, 4, 'No', 'East')
# (83600, 1990, 3, 3, 4, 'No', 'North')
# (90300, 2050, 3, 2, 6, 'No', 'North')
# (90500, 1520, 2, 2, 3, 'No', 'North')
# (91100, 1860, 2, 2, 3, 'No', 'North')
# (91700, 1690, 3, 2, 3, 'No', 'North')
# (93600, 2140, 3, 2, 4, 'No', 'North')
# (94700, 1980, 3, 2, 3, 'No', 'East')
# (97800, 2010, 2, 2, 4, 'No', 'North')
# (99300, 1700, 3, 2, 2, 'No', 'East')
# (100900, 1610, 2, 2, 2, 'No', 'North')
# (102500, 1900, 3, 3, 3, 'No', 'North')
# (102600, 1910, 3, 2, 4, 'No', 'North')
# (102700, 1900, 4, 2, 4, 'No', 'North')
# (103200, 1810, 3, 2, 3, 'No', 'East')
# (103200, 2010, 3, 2, 5, 'No', 'North')
# (104000, 1730, 3, 3, 3, 'No', 'East')
# (105600, 1990, 2, 2, 3, 'No', 'East')
# (105600, 1930, 3, 3, 3, 'No', 'East')
# (106100, 1820, 3, 2, 3, 'Yes', 'North')
# (106600, 1560, 2, 2, 1, 'No', 'East')
# (106900, 1900, 2, 2, 2, 'No', 'North')
# (107300, 1650, 3, 2, 3, 'No', 'North')
# (107500, 1700, 3, 2, 3, 'Yes', 'North')
# (108200, 1740, 3, 2, 2, 'No', 'North')
# (108500, 2130, 3, 2, 4, 'No', 'North')
# (108700, 2110, 3, 2, 3, 'No', 'East')
# (109700, 1920, 2, 2, 4, 'No', 'North')
# (110400, 1930, 2, 3, 3, 'No', 'North')
# (111100, 1450, 2, 2, 1, 'Yes', 'North')
# (111400, 1700, 2, 2, 1, 'Yes', 'East')
# (111600, 1710, 2, 2, 1, 'No', 'North')
# (112300, 1930, 2, 2, 2, 'Yes', 'North')
# (113500, 2070, 2, 2, 2, 'No', 'North')
# (113800, 2000, 3, 2, 4, 'No', 'North')
# (114200, 2030, 4, 2, 3, 'No', 'East')
# (114300, 1790, 2, 2, 2, 'No', 'East')
# (114600, 1780, 3, 2, 2, 'No', 'North')
# (114800, 1740, 3, 2, 1, 'No', 'East')
# (114900, 1740, 2, 2, 2, 'No', 'North')
# (115700, 2000, 3, 2, 3, 'Yes', 'North')
# (115900, 1980, 2, 2, 2, 'No', 'East')
# (116200, 1790, 3, 2, 3, 'No', 'East')
# (116500, 2150, 3, 2, 2, 'No', 'East')
# (117000, 1990, 3, 3, 3, 'Yes', 'East')
# (117100, 2080, 3, 3, 3, 'No', 'North')
# (117400, 2150, 2, 3, 4, 'No', 'North')
# (117500, 1880, 2, 2, 2, 'No', 'North')
# (117800, 2000, 2, 2, 3, 'No', 'North')
# (117800, 1920, 3, 2, 2, 'No', 'North')
# (119200, 2110, 4, 2, 3, 'No', 'East')
# (119700, 1900, 3, 3, 3, 'Yes', 'East')
# (119800, 2130, 3, 3, 3, 'No', 'East')
# (120500, 1910, 2, 3, 2, 'No', 'East')
# (121300, 2130, 3, 2, 3, 'No', 'North')
# (123000, 1870, 2, 2, 2, 'Yes', 'East')
# (123100, 2260, 3, 3, 5, 'No', 'East')
# (123600, 1940, 2, 2, 2, 'Yes', 'East')
# (124500, 2010, 4, 3, 2, 'No', 'East')
# (124600, 2250, 3, 3, 4, 'No', 'North')
# (125700, 1720, 2, 2, 2, 'Yes', 'East')
# (125700, 2040, 3, 3, 2, 'No', 'East')
# (126200, 2210, 3, 3, 4, 'No', 'North')
# (126300, 2150, 3, 3, 5, 'Yes', 'North')
# (126800, 2000, 2, 2, 1, 'Yes', 'East')
# (127700, 1930, 3, 3, 2, 'No', 'North')
# (129800, 1990, 2, 3, 2, 'No', 'North')
# (129800, 1930, 3, 2, 2, 'No', 'West')
# (130300, 1860, 3, 2, 2, 'No', 'West')
# (130800, 2100, 3, 2, 3, 'No', 'North')
# (131300, 1720, 3, 2, 1, 'No', 'West')
# (132500, 2030, 3, 2, 3, 'Yes', 'East')
# (133300, 2440, 3, 3, 3, 'No', 'East')
# (133600, 1840, 4, 3, 2, 'No', 'West')
# (134000, 1890, 3, 2, 1, 'Yes', 'East')
# (135000, 2250, 3, 3, 3, 'Yes', 'East')
# (136800, 2410, 3, 3, 4, 'No', 'East')
# (137000, 2000, 4, 2, 3, 'No', 'West')
# (138100, 1840, 3, 3, 1, 'No', 'West')
# (139600, 2280, 5, 3, 4, 'Yes', 'East')
# (140900, 2190, 3, 2, 3, 'Yes', 'East')
# (142600, 2110, 3, 2, 2, 'No', 'West')
# (143100, 1920, 4, 2, 2, 'No', 'West')
# (143400, 2190, 3, 3, 4, 'Yes', 'East')
# (143600, 1780, 4, 2, 1, 'No', 'West')
# (144200, 2140, 3, 3, 3, 'No', 'West')
# (144800, 2060, 2, 2, 1, 'Yes', 'East')
# (145500, 2060, 3, 2, 1, 'No', 'West')
# (145800, 1780, 4, 2, 1, 'No', 'West')
# (146900, 2530, 4, 3, 4, 'No', 'West')
# (147000, 2420, 4, 3, 4, 'No', 'West')
# (147100, 2190, 3, 3, 4, 'Yes', 'East')
# (147700, 2410, 3, 3, 2, 'No', 'East')
# (147900, 2160, 4, 3, 3, 'Yes', 'East')
# (149300, 2290, 4, 3, 3, 'No', 'North')
# (149900, 2020, 3, 3, 1, 'No', 'West')
# (150200, 1950, 3, 2, 3, 'Yes', 'North')
# (150700, 2160, 4, 2, 2, 'No', 'West')
# (151100, 2100, 3, 2, 3, 'Yes', 'East')
# (151600, 1830, 3, 3, 3, 'Yes', 'West')
# (151900, 2040, 4, 3, 3, 'No', 'East')
# (152300, 2240, 4, 3, 3, 'No', 'West')
# (152500, 1970, 2, 2, 1, 'Yes', 'West')
# (154000, 1920, 3, 2, 1, 'Yes', 'East')
# (155400, 2090, 4, 2, 1, 'No', 'West')
# (156400, 2210, 4, 3, 2, 'Yes', 'East')
# (157100, 2080, 3, 3, 2, 'No', 'East')
# (157600, 2160, 4, 2, 1, 'No', 'West')
# (160600, 2150, 4, 3, 3, 'Yes', 'West')
# (161300, 2220, 4, 3, 2, 'No', 'West')
# (164800, 2050, 2, 2, 1, 'Yes', 'West')
# (165600, 2080, 4, 3, 3, 'No', 'West')
# (166500, 1940, 3, 3, 2, 'Yes', 'West')
# (166700, 1950, 3, 3, 3, 'Yes', 'West')
# (167200, 1920, 3, 3, 2, 'Yes', 'West')
# (171000, 2080, 3, 3, 2, 'Yes', 'West')
# (172500, 1880, 3, 3, 1, 'Yes', 'West')
# (176500, 2280, 4, 3, 3, 'Yes', 'West')
# (176800, 2590, 4, 3, 4, 'No', 'West')
# (180900, 2200, 3, 3, 1, 'No', 'West')
# (182000, 2250, 4, 3, 3, 'Yes', 'West')
# (184300, 2140, 4, 3, 2, 'Yes', 'West')
# (188000, 2040, 4, 3, 1, 'Yes', 'West')
# (188300, 2250, 4, 3, 2, 'Yes', 'West')
# (199500, 2290, 5, 4, 1, 'Yes', 'West')
# (211200, 2440, 4, 3, 3, 'Yes', 'West')

# %%
df
# Out:
#          Nama gender  angkatan  tinggi (Cm)  waktu perjalanan           Asal
# 0       Dave       L      2023          168                60      Tangerang
# 1   Francisco      L      2023          170                30      rusunawa
# 2       Abyan      L      2023          165                45          Priuk
# 3     Michael      L      2023          167                15      Jkt Utara
# 4    partahi       L      2023          173                45      jkt utara
# 5     hafidz       L      2023          169                15         Grogol
# 6   Francisco      L      2023          170                30      rusunawa
# 7     Rayyan       L      2023          171                50      Jkt Timur
# 8   Yustianas      L      2023          173                30     Jkt Utara
# 9      Zahwa       P      2023          154                15         grogol
# 10      Dave       L      2023          168                60     Tangerang
# 11   Calista       P      2023          160               150         Bekasi
# 12     Fairuz      P      2023          156                45          Priok
# 13      Gwen       P      2023          152                17         Gambir
# 14     Briant      L      2023          167                10        Tawakal
# 15     ariel       L      2023          170                35     Klp gading
# 16     Ridho       L      2023          170                45     Cengkareng
# 17      Monic      P      2023          160                75      Jkt Timur
# 18      Sutan      L      2023          170                90        Sunter
# 19   Zulfadli      L      2023          170                45    Kp Makasar
# 20     Andrew      L      2023          172                13         tomang
# 21      ariel      L      2023          170                35     klp gading
# 22      Arik       L      2023          177                60      Tangerang
# 23   Calista       P      2023          160               150         Bekasi
# 24   Dewanto       L      2023          172                40       Tj Priok
# 25     Fadhil      L      2023          169                60         Cipadu
# 26     Kevin       L      2023          173                60    Duren Sawit
# 27     fadly       L      2023          174                75          Depok
# 28     Hakim       L      2023          170                10     Tamansari
# 29   Rayyan        L      2023          171                50      Jkt Timur
# 30   Mutiara       P      2023          160                60        Pejaten
# 31    Noval s      L      2023          177                60          Depok
# 32      HAQI       L      2023          171                60      Tangerang
# 33    rafael       L      2023          175                15  gunung sahari
# 34    Rangga       L      2023          185                90    Kota Bekasi

# %%
rata2tinggi=df['tinggi (Cm)'].mean()
rata2tinggi
# Out:
# 168.54285714285714

# %%
print(df.dtypes)
# Out:
# Nama                object
# gender              object
# angkatan             int64
# tinggi (Cm)          int64
# waktu perjalanan     int64
# Asal                object
# dtype: object

# %%
df['angkatan']=df['angkatan'].astype(str)
print(df.dtypes)
# Out:
# Nama                object
# gender              object
# angkatan            object
# tinggi (Cm)          int64
# waktu perjalanan     int64
# Asal                object
# dtype: object

# %%
import pandas as pd

# Membaca file CSV
df = pd.read_csv('C:/Users/HAFIDZ R/Downloads/1Data.csv', sep=';')


# Menghapus spasi ekstra pada setiap kolom
df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# Menampilkan ringkasan statistik untuk kolom numerik
numeric_summary = df.describe()
print(numeric_summary)
# Out:
#        angkatan  tinggi (Cm)  waktu perjalanan  Unnamed: 6
# count      35.0    35.000000         35.000000         0.0
# mean     2023.0   168.542857         49.857143         NaN
# std         0.0     6.766452         33.291178         NaN
# min      2023.0   152.000000         10.000000         NaN
# 25%      2023.0   167.000000         30.000000         NaN
# 50%      2023.0   170.000000         45.000000         NaN
# 75%      2023.0   172.000000         60.000000         NaN
# max      2023.0   185.000000        150.000000         NaN
# C:\Users\HAFIDZ R\AppData\Local\Temp\ipykernel_1424\1141580197.py:8: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# %%
import pandas as pd

# Membaca file CSV
df = pd.read_csv('C:/Users/HAFIDZ R/Downloads/1Data.csv', sep=';')

# Menghapus spasi ekstra pada setiap kolom
df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# Menghapus kolom 'Unnamed: 6'
df = df.drop(columns=['Unnamed: 6'])

# Menghapus baris yang hanya berisi nilai NaN
df = df.dropna()

# Menampilkan DataFrame
print(df)
# Out:
#          Nama gender  angkatan  tinggi (Cm)  waktu perjalanan           Asal
# 0        Dave      L    2023.0        168.0              60.0      Tangerang
# 1   Francisco      L    2023.0        170.0              30.0       rusunawa
# 2       Abyan      L    2023.0        165.0              45.0          Priuk
# 3     Michael      L    2023.0        167.0              15.0      Jkt Utara
# 4     partahi      L    2023.0        173.0              45.0      jkt utara
# 5      hafidz      L    2023.0        169.0              15.0         Grogol
# 6   Francisco      L    2023.0        170.0              30.0       rusunawa
# 7      Rayyan      L    2023.0        171.0              50.0      Jkt Timur
# 8   Yustianas      L    2023.0        173.0              30.0      Jkt Utara
# 9       Zahwa      P    2023.0        154.0              15.0         grogol
# 10       Dave      L    2023.0        168.0              60.0      Tangerang
# 11    Calista      P    2023.0        160.0             150.0         Bekasi
# 12     Fairuz      P    2023.0        156.0              45.0          Priok
# 13       Gwen      P    2023.0        152.0              17.0         Gambir
# 14     Briant      L    2023.0        167.0              10.0        Tawakal
# 15      ariel      L    2023.0        170.0              35.0     Klp gading
# 16      Ridho      L    2023.0        170.0              45.0     Cengkareng
# 17      Monic      P    2023.0        160.0              75.0      Jkt Timur
# 18      Sutan      L    2023.0        170.0              90.0         Sunter
# 19   Zulfadli      L    2023.0        170.0              45.0     Kp Makasar
# 20     Andrew      L    2023.0        172.0              13.0         tomang
# 21      ariel      L    2023.0        170.0              35.0     klp gading
# 22       Arik      L    2023.0        177.0              60.0      Tangerang
# 23    Calista      P    2023.0        160.0             150.0         Bekasi
# 24    Dewanto      L    2023.0        172.0              40.0       Tj Priok
# 25     Fadhil      L    2023.0        169.0              60.0         Cipadu
# 26      Kevin      L    2023.0        173.0              60.0    Duren Sawit
# 27      fadly      L    2023.0        174.0              75.0          Depok
# 28      Hakim      L    2023.0        170.0              10.0      Tamansari
# 29     Rayyan      L    2023.0        171.0              50.0      Jkt Timur
# 30    Mutiara      P    2023.0        160.0              60.0        Pejaten
# 31    Noval s      L    2023.0        177.0              60.0          Depok
# 32       HAQI      L    2023.0        171.0              60.0      Tangerang
# 33     rafael      L    2023.0        175.0              15.0  gunung sahari
# 34     Rangga      L    2023.0        185.0              90.0    Kota Bekasi
# C:\Users\HAFIDZ R\AppData\Local\Temp\ipykernel_1424\351018473.py:7: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# %%
import pandas as pd

# Membaca file Excel (xlsx)
df = pd.read_excel('C:/Users/HAFIDZ R/Downloads/1Data.xlsx')

# Menghapus spasi ekstra pada setiap kolom
df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# Menghapus kolom 'Unnamed: 6' jika ada
if 'Unnamed: 6' in df.columns:
    df = df.drop(columns=['Unnamed: 6'])

# Menghapus baris yang hanya berisi nilai NaN
df = df.dropna()

# Menampilkan DataFrame
print(df)
# Out:
#          Nama gender  angkatan  tinggi (Cm)  waktu perjalanan           Asal
# 0        Dave      L      2023          168                60      Tangerang
# 1   Francisco      L      2023          170                30       rusunawa
# 2       Abyan      L      2023          165                45          Priuk
# 3     Michael      L      2023          167                15      Jkt Utara
# 4     partahi      L      2023          173                45      jkt utara
# 5      hafidz      L      2023          169                15         Grogol
# 6   Francisco      L      2023          170                30       rusunawa
# 7      Rayyan      L      2023          171                50      Jkt Timur
# 8   Yustianas      L      2023          173                30      Jkt Utara
# 9       Zahwa      P      2023          154                15         grogol
# 10       Dave      L      2023          168                60      Tangerang
# 11    Calista      P      2023          160               150         Bekasi
# 12     Fairuz      P      2023          156                45          Priok
# 13       Gwen      P      2023          152                17         Gambir
# 14     Briant      L      2023          167                10        Tawakal
# 15      ariel      L      2023          170                35     Klp gading
# 16      Ridho      L      2023          170                45     Cengkareng
# 17      Monic      P      2023          160                75      Jkt Timur
# 18      Sutan      L      2023          170                90         Sunter
# 19   Zulfadli      L      2023          170                45     Kp Makasar
# 20     Andrew      L      2023          172                13         tomang
# 21      ariel      L      2023          170                35     klp gading
# 22       Arik      L      2023          177                60      Tangerang
# 23    Calista      P      2023          160               150         Bekasi
# 24    Dewanto      L      2023          172                40       Tj Priok
# 25     Fadhil      L      2023          169                60         Cipadu
# 26      Kevin      L      2023          173                60    Duren Sawit
# 27      fadly      L      2023          174                75          Depok
# 28      Hakim      L      2023          170                10      Tamansari
# 29     Rayyan      L      2023          171                50      Jkt Timur
# 30    Mutiara      P      2023          160                60        Pejaten
# 31    Noval s      L      2023          177                60          Depok
# 32       HAQI      L      2023          171                60      Tangerang
# 33     rafael      L      2023          175                15  gunung sahari
# 34     Rangga      L      2023          185                90    Kota Bekasi
# C:\Users\HAFIDZ R\AppData\Local\Temp\ipykernel_1424\4180884850.py:7: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# %%
import pandas as pd

# Membaca file CSV dan membuat DataFrame
df = pd.read_csv('C:/Users/HAFIDZ R/Downloads/houseprices.csv')

# Melakukan filter data berdasarkan kolom 'Brick' yang bernilai 'No'
df_filtered = df[df['Brick'] == 'No']

# Menampilkan hasil filter
print(df_filtered)
# Out:
#       Price  SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood
# 0    114300  1790         2          2       2    No         East
# 1    114200  2030         4          2       3    No         East
# 2    114800  1740         3          2       1    No         East
# 3     94700  1980         3          2       3    No         East
# 4    119800  2130         3          3       3    No         East
# ..      ...   ...       ...        ...     ...   ...          ...
# 120  110400  1930         2          3       3    No        North
# 121  105600  1930         3          3       3    No         East
# 125  113500  2070         2          2       2    No        North
# 126  149900  2020         3          3       1    No         West
# 127  124600  2250         3          3       4    No        North
#
# [86 rows x 7 columns]

# %%
import pandas as pd

# df adalah DataFrame Anda, yang telah diinisialisasi sebelumnya

# Filter data berdasarkan kondisi yang kompleks
df_filtered = df[(df['Brick'] == 'No') | (df['Neighborhood'] == 'East')]

# Menampilkan hasil filter
print(df_filtered)
# Out:
#       Price  SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood
# 0    114300  1790         2          2       2    No         East
# 1    114200  2030         4          2       3    No         East
# 2    114800  1740         3          2       1    No         East
# 3     94700  1980         3          2       3    No         East
# 4    119800  2130         3          3       3    No         East
# ..      ...   ...       ...        ...     ...   ...          ...
# 123  119700  1900         3          3       3   Yes         East
# 124  147900  2160         4          3       3   Yes         East
# 125  113500  2070         2          2       2    No        North
# 126  149900  2020         3          3       1    No         West
# 127  124600  2250         3          3       4    No        North
#
# [105 rows x 7 columns]

# %%
df = pd.read_excel('C:/Users/HAFIDZ R/Downloads/data_prak_distribusi.xlsx')
df.head(15)
# Out:
#    LOKASI UNIT KERJA LAMA LOKASI UNIT KERJA BARU  TUNJANGAN HARIAN  \
# 0                 JAKARTA               SEMARANG           8500000
# 1                 JAKARTA               SEMARANG           9000000
# 2                 JAKARTA               SEMARANG          11250000
# 3                 JAKARTA             JOGYAKARTA           2250000
# 4                SURABAYA                 MANADO           4500000
# 5               TANGERANG             JOGYAKARTA           3500000
# 6                 JAKARTA             JOGYAKARTA           2125000
# 7                  MANADO                JAKARTA           2250000
# 8                   BOGOR             JOGYAKARTA           4250000
# 9                 JAKARTA               BOYOLALI          10625000
# 10                JAKARTA               SURABAYA           2250000
# 11               SURABAYA                 MADIUN           2125000
# 12                 MADIUN                JAKARTA           2125000
# 13                  MEDAN                 BEKASI           2500000
# 14               SURABAYA                JAKARTA           2125000
#
#     PENGEPAKAN BARANG  BIAYA HOTEL
# 0             2400000      6400000
# 1             2400000      6400000
# 2             3000000      9600000
# 3             1200000      3200000
# 4             7200000      3200000
# 5             1800000      4000000
# 6              600000      3200000
# 7             6400000      3200000
# 8              600000      3200000
# 9             2300000      9600000
# 10            2000000      3200000
# 11             800000      3200000
# 12            2000000      3200000
# 13            3800000      3200000
# 14             400000      3200000

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Baca file Excel
df = pd.read_excel('C:/Users/HAFIDZ R/Downloads/data_prak_distribusi.xlsx')

# Pilih kolom yang ingin digunakan
kolom_pilihan = 'BIAYA HOTEL'

# Ambil data dari kolom yang dipilih
data_nama = df[kolom_pilihan]

# Hitung rata-rata dan standar deviasi dari data
mean_nama = np.mean(data_nama)
stddev_nama = np.std(data_nama)

# Cetak statistik deskriptif
print("Rata-rata dari kolom (kolom pilihan):", mean_nama)
print("Standar Deviasi dari kolom (kolom_pilihan):", stddev_nama)

# Plot distribusi normal
x = np.linspace(min(data_nama), max(data_nama), 100)
plt.plot(x, norm.pdf(x, mean_nama, stddev_nama), label='Distribusi Normal')

# Plot histogram dari data
plt.hist(data_nama, bins=30, density=True, alpha=0.6, color='g', label='Histogram')

plt.title('Praktikum Distribusi Normal')
plt.xlabel('Nilai')
plt.ylabel('Frekuensi Relatif')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Rata-rata dari kolom (kolom pilihan): 4023300.9708737866
# Standar Deviasi dari kolom (kolom_pilihan): 1472413.2416128046

# %%
import numpy as np
from scipy.stats import bernoulli
import matplotlib.pyplot as plt

# Probabilitas keberhasilan (p)
p = 0.5

# Menentukan distribusi Bernoulli
distribusi_bernoulli = bernoulli(p)

# Menghitung probabilitas untuk nilai 0 dan 1
probabilitas_0 = distribusi_bernoulli.pmf(0)
probabilitas_1 = distribusi_bernoulli.pmf(1)

# Menghitung rata-rata (mean) dan varians
rata_rata = distribusi_bernoulli.mean()
varians = distribusi_bernoulli.var()

# Mencetak hasil analisis
print('Probabilitas (0):', probabilitas_0)
print('Probabilitas (1):', probabilitas_1)
print('Rata-rata:', rata_rata)
print('Varians:', varians)
# Memvisualisasikan distribusi Bernoulli
plt.plot(np.arange(2), distribusi_bernoulli.pmf(np.arange(2)), 'bo-')
plt.xlabel("Nilai Data")
plt.ylabel("Probabilitas")
plt.title("Distribusi Bernoulli")
plt.show()
# Out:
# Probabilitas (0): 0.5000000000000001
# Probabilitas (1): 0.5
# Rata-rata: 0.5
# Varians: 0.25

# %%
# Distribusi Binomial

import numpy as np
from scipy.stats import binom
import matplotlib.pyplot as plt

# Jumlah percobaan (n)
n = 10

# Probabilitas keberhasilan (p)
p = 0.5

# Menentukan distribusi binomial
distribusi_binom = binom(n, p)

# Menghitung probabilitas untuk k = 0, 1, ..., n
probabilitas = distribusi_binom.pmf(np.arange(n + 1))

# Menghitung rata-rata (mean) dan varians
rata_rata = distribusi_binom.mean()
varians = distribusi_binom.var()

# Mencetak hasil analisis
print('Probabilitas:', probabilitas)
print('Rata-rata:', rata_rata)
print('Varian:', varians)

# Memvisualisasikan distribusi binomial
plt.plot(np.arange(n + 1), probabilitas, 'bo-')
plt.xlabel('Jumlah Keberhasilan (k)')
plt.ylabel('Probabilitas')
plt.title('Distribusi Binomial')
plt.show()
# Out:
# Probabilitas: [0.00097656 0.00976563 0.04394531 0.1171875  0.20507812 0.24609375
#  0.20507812 0.1171875  0.04394531 0.00976563 0.00097656]
# Rata-rata: 5.0
# Varian: 2.5
